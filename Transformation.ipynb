# %%
## Standard normal distribution
np.random.normal(0, 1, 100)
# Out:
# array([-1.15969505,  2.86255019,  0.10342266, -0.8696452 , -1.5450772 ,
#         0.95310374, -0.44487015, -0.38305583, -0.43208452,  0.15868117,
#         0.80351689,  1.02950067,  0.43337867,  0.19486586,  0.25871979,
#        -1.50597371, -1.60619074, -2.95007954,  0.73975937, -0.72662269,
#        -0.4924083 , -0.22922217,  0.86530424,  0.01273375, -0.57140795,
#         0.09002161,  0.6494595 , -0.67493459, -2.11277359, -0.06723113,
#        -0.12983149,  0.72372535,  0.51125664,  0.5010916 ,  1.16977131,
#         0.1687317 ,  0.50820494,  0.82669638, -0.46964615, -0.29002576,
#         0.81389886, -0.17298231, -0.72629095, -0.17402049, -0.8771037 ,
#         0.17984978,  0.84843897, -0.62910737, -0.221386  ,  1.15646005,
#         1.0829509 ,  1.47075021, -1.93022316, -0.54790432,  0.57116393,
#        -0.93215753,  0.89886573, -2.04900357,  1.4677355 , -0.68146436,
#        -1.54247549,  0.17068974,  0.14734363, -0.91911839, -0.45841337,
#        -1.16424439, -0.94263672,  1.35980353,  1.11376882,  0.68225575,
#         1.19903804, -0.69592148, -1.39189402, -0.97517616,  1.15314839,
#        -0.05129106,  2.32429666,  0.83866824,  1.12628026,  1.0002285 ,
#         0.64077621, -1.05599609, -0.6838917 ,  1.66504809, -3.2678695 ,
#         1.48941911, -0.03038225, -0.14882139, -0.52690703, -1.11102119,
#        -0.01712666, -0.36934925,  1.34238618,  0.05669603, -0.43027472,
#         0.01857028,  0.27919066,  1.0775877 , -0.13263056,  0.52060318])

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py

# np.random generates different random numbers
# whenever the code is executed
# Note: When you execute the same code
# the graph look different than shown below.

# Random data points generated
data_points = np.random.normal(0, 1, 100)	

sm.qqplot(data_points, line ='45')
py.show()

# %%
import seaborn as sns
sns.displot(gfg,kind="kde")

# %%
### Create Log Normal Distributed data
# import numpy
import numpy as np
  
# using np.lognormal() method
gfg = np.random.lognormal(0, 1, 100)


  
print(gfg)
# Out:
# [ 1.17381111  1.39898447  0.26598959  0.31278573  7.10097841  0.14789688
#   0.84879722  0.30354319  0.46096324  3.3340833   1.00777165  1.79108258
#   0.29683145  0.2919004   3.86211579  5.14224009  0.35495895  0.52253475
#   0.20964539  1.61758038  0.71958194  5.32408659  1.02643233  0.81252166
#   2.59745549  1.86431932  0.35780071  5.40250052  0.95988158  9.06560015
#   0.07542884  0.6675538   0.61720494  0.22296886  1.26800921  3.37558129
#   0.74702601  4.65248031  0.32946604  0.54541171  1.5049616   1.15254567
#   0.67291627  0.16097168  0.54223336  0.64906653  1.5260389   0.50305777
#   0.92618711  4.75392894  2.7503325   1.64808818  4.50120647  0.61895849
#   1.73805644  0.47378439  0.56231514  1.76331236  0.77816391  2.47726761
#   1.11784267  9.86012648  5.19283828  1.49847662  2.43598002  2.2621879
#   0.84796209  0.78020112  0.22240983  0.56609717  0.22561493  0.200674
#   0.32036563  1.95867053  0.52497807  0.03380141  0.47880381  1.85630018
#  10.40973766  1.40171459  1.07151177  3.11485013 10.10483993  0.80704127
#   0.2989002   0.41999802  0.94778582  0.32902722  0.87992827  3.71440468
#   2.20732239  0.65803122  0.1317626   0.65880511  0.82795426  1.13112514
#   2.45548901  2.68756277  0.16008543  0.66026284]

# %%
np.log(gfg)
# Out:
# array([ 0.16025581,  0.3357466 , -1.3242981 , -1.16223688,  1.96023258,
#        -1.91123999, -0.16393497, -1.19223138, -0.77443699,  1.20419777,
#         0.0077416 ,  0.58282023, -1.2145908 , -1.23134263,  1.35121517,
#         1.6374888 , -1.03575312, -0.64906379, -1.56233782,  0.48093144,
#        -0.32908487,  1.67224117,  0.02608904, -0.20761271,  0.95453231,
#         0.62289601, -1.02777912,  1.6868619 , -0.04094535,  2.20448705,
#        -2.5845656 , -0.40413529, -0.48255415, -1.50072316,  0.23744812,
#         1.21656754, -0.29165527,  1.53740048, -1.110282  , -0.60621433,
#         0.40876738,  0.14197312, -0.39613437, -1.8265268 , -0.61205881,
#        -0.43222006,  0.42267543, -0.68705027, -0.076679  ,  1.55897142,
#         1.01172182,  0.49961594,  1.50434546, -0.47971707,  0.5527675 ,
#        -0.74700293, -0.57569285,  0.56719406, -0.2508181 ,  0.90715618,
#         0.11140064,  2.288499  ,  1.64728042,  0.40444901,  0.89034915,
#         0.81633244, -0.16491935, -0.24820355, -1.5032335 , -0.56898954,
#        -1.48892559, -1.60607356, -1.13829235,  0.67226594, -0.64439878,
#        -3.3872527 , -0.73646435,  0.61858536,  2.34274168,  0.33769619,
#         0.06907052,  1.13618104,  2.31301451, -0.21438047, -1.20764553,
#        -0.86750528, -0.05362673, -1.1116148 , -0.12791488,  1.31221842,
#         0.79178019, -0.41850291, -2.02675345, -0.41732752, -0.18879737,
#         0.12321284,  0.89832593,  0.98863475, -1.83204769, -0.41511728])

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py

# np.random generates different random numbers
# whenever the code is executed
# Note: When you execute the same code
# the graph look different than shown below.

# Random data points generated

sm.qqplot(np.log(gfg), line ='45')
py.show()
